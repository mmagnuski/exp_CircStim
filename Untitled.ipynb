# %%
import numpy as np
import pandas as pd
from weibull import *

# %%
import os

# %%
os.getcwd()
# Out:
# 'e:\\Programy\\EXP\\exp_CircStim'

# %%
pth = os.path.join(os.getcwd(), 'data')
df = pd.read_excel(os.path.join(pth, '124_b.xls'))
df.head()
# Out:
#         time  fixTime  targetTime  SMI  maskTime  opacity  orientation  \
# 1   7.597895      148           1    2        20      1.0          135
# 2  10.604024       95           1    2        20      0.9           90
# 3  12.737290       98           1    2        20      0.8           45
# 4  15.637113      115           1    2        20      0.7           45
# 5  18.253515      106           1    2        20      0.6            0
#
#   response  ifcorrect             RT
# 1        j          1 -156590.857530
# 2        f          1 -156590.862756
# 3        j          1 -156590.141941
# 4        j          1 -156590.709097
# 5        f          1 -156590.879543

# %%
ind = [10, 11, 12, 13, 14, 15, 16, 17, 18]
df.loc[ind, :]
# Out:
#          time  fixTime  targetTime  SMI  maskTime  opacity  orientation  \
# 10  31.785767      131           1    2        20     0.30            0
# 11  34.368908      136           1    2        20     0.40            0
# 12  37.218724       83           1    2        20     0.45           90
# 13  39.285323       67           1    2        20     0.50            0
# 14  40.951758       72           1    2        20     0.55          135
# 15  42.968460       97           1    2        20     0.60            0
# 16        NaN      116           1    2        20      NaN           45
# 17        NaN       67           1    2        20      NaN          135
# 18        NaN      138           1    2        20      NaN           45
#
#    response  ifcorrect             RT
# 10        j          0 -156591.032821
# 11        j          0 -156590.831286
# 12        j          0 -156590.733490
# 13        j          0 -156590.869607
# 14        f          0 -156590.603588
# ...

# %%
w = fitw(df, ind)
w.plot()
# Out:
# x:  [ 0.3   0.4   0.45  0.5   0.55  0.6    nan   nan   nan]
# k:  0.69314718056
# expo [ 0.20794415  0.27725887  0.31191623  0.34657359  0.38123095  0.41588831
#          nan         nan         nan]
# x:  [ 0.3   0.4   0.45  0.5   0.55  0.6    nan   nan   nan]
# k:  0.705350861302
# expo [ 0.19579553  0.26484297  0.29970818  0.33476802  0.37000389  0.40540049
#          nan         nan         nan]
# x:  [ 0.3   0.4   0.45  0.5   0.55  0.6    nan   nan   nan]
# k:  0.69314718056
# expo [ 0.19804205  0.26405607  0.29706308  0.33007009  0.36307709  0.3960841
#          nan         nan         nan]
# x:  [ 0.3   0.4   0.45  0.5   0.55  0.6    nan   nan   nan]
# k:  0.705350861302
# expo [ 0.20662982  0.27949798  0.31629244  0.35329231  0.39047794  0.42783321
#          nan         nan         nan]
# x:  [ 0.3   0.4   0.45  0.5   0.55  0.6    nan   nan   nan]
# k:  0.696290674742
# expo [ 0.19978037  0.26733344  0.30119324  0.33510019  0.36904963  0.40303772
# ...
